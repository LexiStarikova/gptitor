# %%
from sqlalchemy import create_engine, Column, Integer, String, DateTime, ForeignKey, Table
from sqlalchemy.orm import declarative_base, relationship, sessionmaker
from sqlalchemy_json import NestedMutableJson

engine = create_engine('sqlite:///gptitor.db', echo=True)

Base = declarative_base()

# Define association table for Conversations <-> Messages (many-to-many relationship)
conversation_message_association = Table(
    'conversation_message_association',
    Base.metadata,
    Column('conversation_id', Integer, ForeignKey('conversations.conversation_id')),
    Column('message_id', Integer, ForeignKey('messages.message_id'))
)

# Define User model
class User(Base):
    __tablename__ = 'users'
    user_id = Column(Integer, primary_key=True, autoincrement=True)
    token = Column(String)
    name = Column(String)

# Define Conversation model
class Conversation(Base):
    __tablename__ = 'conversations'
    conversation_id = Column(Integer, primary_key=True, autoincrement=True)
    title = Column(String)
    user_id = Column(Integer, ForeignKey('users.user_id'))
    messages = relationship('Message', secondary=conversation_message_association, backref='conversations')
    llm_id = Column(Integer, ForeignKey('aimodels.llm_id'))
    created_at = Column(DateTime)

# Define AIModels model
class AIModel(Base):
    __tablename__ = 'aimodels'
    llm_id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String)
    api = Column(String)

# Define Message model
class Message(Base):
    __tablename__ = 'messages'
    message_id = Column(Integer, primary_key=True, autoincrement=True)
    conversation_id = Column(Integer, ForeignKey('conversations.conversation_id'))
    message_class = Column(String)
    content = Column(String)
    feedback_id = Column(Integer)
    created_at = Column(DateTime)

# Define Feedback model (document-oriented table)
class Feedback(Base):
    __tablename__ = 'feedback'
    feedback_id = Column(Integer, primary_key=True, autoincrement=True)
    comment = Column(String)
    metrics = Column(NestedMutableJson)
    
class Task(Base):
    __tablename__ = 'tasks'
    task_id = Column(Integer, primary_key=True, autoincrement=True)
    task_category = Column(String)
    task_name = Column(String)
    task_description = Column(String)

# Create all tables in the database
Base.metadata.create_all(engine)
# Out:
# 2024-06-30 05:51:37,409 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 05:51:37,412 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("conversation_message_association")
# 2024-06-30 05:51:37,413 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,417 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("conversation_message_association")
# 2024-06-30 05:51:37,418 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,419 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("users")
# 2024-06-30 05:51:37,420 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,421 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("users")
# 2024-06-30 05:51:37,422 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,424 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("conversations")
# 2024-06-30 05:51:37,425 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,427 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("conversations")
# 2024-06-30 05:51:37,428 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,431 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("aimodels")
# 2024-06-30 05:51:37,432 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,432 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("aimodels")
# 2024-06-30 05:51:37,433 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,433 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("messages")
# 2024-06-30 05:51:37,434 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,435 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("messages")
# 2024-06-30 05:51:37,436 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,436 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("feedback")
# 2024-06-30 05:51:37,437 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,438 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("feedback")
# 2024-06-30 05:51:37,439 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,440 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("tasks")
# 2024-06-30 05:51:37,440 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,441 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("tasks")
# 2024-06-30 05:51:37,441 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 05:51:37,444 INFO sqlalchemy.engine.Engine
# CREATE TABLE users (
# 	user_id INTEGER NOT NULL,
# 	token VARCHAR,
# 	name VARCHAR,
# 	PRIMARY KEY (user_id)
# )
#
#
# 2024-06-30 05:51:37,445 INFO sqlalchemy.engine.Engine [no key 0.00061s] ()
# 2024-06-30 05:51:37,451 INFO sqlalchemy.engine.Engine
# CREATE TABLE aimodels (
# 	llm_id INTEGER NOT NULL,
# 	name VARCHAR,
# 	api VARCHAR,
# 	PRIMARY KEY (llm_id)
# )
#
#
# 2024-06-30 05:51:37,451 INFO sqlalchemy.engine.Engine [no key 0.00054s] ()
# 2024-06-30 05:51:37,456 INFO sqlalchemy.engine.Engine
# CREATE TABLE feedback (
# 	feedback_id INTEGER NOT NULL,
# 	comment VARCHAR,
# 	metrics JSON,
# 	PRIMARY KEY (feedback_id)
# )
#
#
# 2024-06-30 05:51:37,457 INFO sqlalchemy.engine.Engine [no key 0.00071s] ()
# 2024-06-30 05:51:37,466 INFO sqlalchemy.engine.Engine
# CREATE TABLE tasks (
# 	task_id INTEGER NOT NULL,
# 	task_category VARCHAR,
# 	task_name VARCHAR,
# 	task_description VARCHAR,
# 	PRIMARY KEY (task_id)
# )
#
#
# 2024-06-30 05:51:37,466 INFO sqlalchemy.engine.Engine [no key 0.00084s] ()
# 2024-06-30 05:51:37,475 INFO sqlalchemy.engine.Engine
# CREATE TABLE conversations (
# 	conversation_id INTEGER NOT NULL,
# 	title VARCHAR,
# 	user_id INTEGER,
# 	llm_id INTEGER,
# 	created_at DATETIME,
# 	PRIMARY KEY (conversation_id),
# 	FOREIGN KEY(user_id) REFERENCES users (user_id),
# 	FOREIGN KEY(llm_id) REFERENCES aimodels (llm_id)
# )
#
#
# 2024-06-30 05:51:37,476 INFO sqlalchemy.engine.Engine [no key 0.00124s] ()
# 2024-06-30 05:51:37,493 INFO sqlalchemy.engine.Engine
# CREATE TABLE messages (
# 	message_id INTEGER NOT NULL,
# 	conversation_id INTEGER,
# 	message_class VARCHAR,
# 	content VARCHAR,
# 	feedback_id INTEGER,
# 	created_at DATETIME,
# 	PRIMARY KEY (message_id),
# 	FOREIGN KEY(conversation_id) REFERENCES conversations (conversation_id)
# )
#
#
# 2024-06-30 05:51:37,496 INFO sqlalchemy.engine.Engine [no key 0.00230s] ()
# 2024-06-30 05:51:37,516 INFO sqlalchemy.engine.Engine
# CREATE TABLE conversation_message_association (
# 	conversation_id INTEGER,
# 	message_id INTEGER,
# 	FOREIGN KEY(conversation_id) REFERENCES conversations (conversation_id),
# 	FOREIGN KEY(message_id) REFERENCES messages (message_id)
# )
#
#
# 2024-06-30 05:51:37,517 INFO sqlalchemy.engine.Engine [no key 0.00124s] ()
# 2024-06-30 05:51:37,528 INFO sqlalchemy.engine.Engine COMMIT
