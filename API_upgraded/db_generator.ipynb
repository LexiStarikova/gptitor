# %%
from sqlalchemy import create_engine, Column, Integer, String, DateTime, ForeignKey, Table
from sqlalchemy.orm import declarative_base, relationship, sessionmaker
from sqlalchemy_json import NestedMutableJson

engine = create_engine('sqlite:///gptitor.db', echo=True)

Base = declarative_base()

# Define association table for Conversations <-> Messages (many-to-many relationship)
conversation_message_association = Table(
    'conversation_message_association',
    Base.metadata,
    Column('conversation_id', Integer, ForeignKey('conversations.conversation_id')),
    Column('message_id', Integer, ForeignKey('messages.message_id'))
)

# Define User model
class User(Base):
    __tablename__ = 'users'
    user_id = Column(Integer, primary_key=True, autoincrement=True)
    token = Column(String)
    name = Column(String)

# Define Conversation model
class Conversation(Base):
    __tablename__ = 'conversations'
    conversation_id = Column(Integer, primary_key=True, autoincrement=True)
    title = Column(String)
    user_id = Column(Integer, ForeignKey('users.user_id'))
    messages = relationship('Message', secondary=conversation_message_association, backref='conversations')
    llm_id = Column(Integer, ForeignKey('aimodels.llm_id'))
    created_at = Column(DateTime)

# Define AIModels model
class AIModel(Base):
    __tablename__ = 'aimodels'
    llm_id = Column(Integer, primary_key=True, autoincrement=True)
    name = Column(String)
    api = Column(String)

# Define Message model
class Message(Base):
    __tablename__ = 'messages'
    message_id = Column(Integer, primary_key=True, autoincrement=True)
    conversation_id = Column(Integer, ForeignKey('conversations.conversation_id'))
    message_class = Column(String)
    content = Column(String)
    feedback_id = Column(Integer)
    created_at = Column(DateTime)

# Define Feedback model (document-oriented table)
class Feedback(Base):
    __tablename__ = 'feedback'
    feedback_id = Column(Integer, primary_key=True, autoincrement=True)
    comment = Column(String)
    metrics = Column(NestedMutableJson)
    
class Task(Base):
    __tablename__ = 'tasks'
    task_id = Column(Integer, primary_key=True, autoincrement=True)
    task_category = Column(String)
    task_name = Column(String)
    task_description = Column(String)

# Create all tables in the database
Base.metadata.create_all(engine)
# Out:
# 2024-06-30 08:40:20,468 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-06-30 08:40:20,469 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("conversation_message_association")
# 2024-06-30 08:40:20,469 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,470 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("conversation_message_association")
# 2024-06-30 08:40:20,471 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,472 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("users")
# 2024-06-30 08:40:20,473 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,474 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("users")
# 2024-06-30 08:40:20,476 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,477 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("conversations")
# 2024-06-30 08:40:20,478 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,479 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("conversations")
# 2024-06-30 08:40:20,480 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,480 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("aimodels")
# 2024-06-30 08:40:20,481 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,481 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("aimodels")
# 2024-06-30 08:40:20,482 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,482 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("messages")
# 2024-06-30 08:40:20,483 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,484 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("messages")
# 2024-06-30 08:40:20,484 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,485 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("feedback")
# 2024-06-30 08:40:20,485 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,486 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("feedback")
# 2024-06-30 08:40:20,486 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,487 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("tasks")
# 2024-06-30 08:40:20,487 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,489 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("tasks")
# 2024-06-30 08:40:20,489 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-06-30 08:40:20,491 INFO sqlalchemy.engine.Engine
# CREATE TABLE users (
# 	user_id INTEGER NOT NULL,
# 	token VARCHAR,
# 	name VARCHAR,
# 	PRIMARY KEY (user_id)
# )
#
#
# 2024-06-30 08:40:20,491 INFO sqlalchemy.engine.Engine [no key 0.00041s] ()
# 2024-06-30 08:40:20,497 INFO sqlalchemy.engine.Engine
# CREATE TABLE aimodels (
# 	llm_id INTEGER NOT NULL,
# 	name VARCHAR,
# 	api VARCHAR,
# 	PRIMARY KEY (llm_id)
# )
#
#
# 2024-06-30 08:40:20,498 INFO sqlalchemy.engine.Engine [no key 0.00061s] ()
# 2024-06-30 08:40:20,502 INFO sqlalchemy.engine.Engine
# CREATE TABLE feedback (
# 	feedback_id INTEGER NOT NULL,
# 	comment VARCHAR,
# 	metrics JSON,
# 	PRIMARY KEY (feedback_id)
# )
#
#
# 2024-06-30 08:40:20,503 INFO sqlalchemy.engine.Engine [no key 0.00054s] ()
# 2024-06-30 08:40:20,508 INFO sqlalchemy.engine.Engine
# CREATE TABLE tasks (
# 	task_id INTEGER NOT NULL,
# 	task_category VARCHAR,
# 	task_name VARCHAR,
# 	task_description VARCHAR,
# 	PRIMARY KEY (task_id)
# )
#
#
# 2024-06-30 08:40:20,508 INFO sqlalchemy.engine.Engine [no key 0.00062s] ()
# 2024-06-30 08:40:20,513 INFO sqlalchemy.engine.Engine
# CREATE TABLE conversations (
# 	conversation_id INTEGER NOT NULL,
# 	title VARCHAR,
# 	user_id INTEGER,
# 	llm_id INTEGER,
# 	created_at DATETIME,
# 	PRIMARY KEY (conversation_id),
# 	FOREIGN KEY(user_id) REFERENCES users (user_id),
# 	FOREIGN KEY(llm_id) REFERENCES aimodels (llm_id)
# )
#
#
# 2024-06-30 08:40:20,514 INFO sqlalchemy.engine.Engine [no key 0.00049s] ()
# 2024-06-30 08:40:20,526 INFO sqlalchemy.engine.Engine
# CREATE TABLE messages (
# 	message_id INTEGER NOT NULL,
# 	conversation_id INTEGER,
# 	message_class VARCHAR,
# 	content VARCHAR,
# 	feedback_id INTEGER,
# 	created_at DATETIME,
# 	PRIMARY KEY (message_id),
# 	FOREIGN KEY(conversation_id) REFERENCES conversations (conversation_id)
# )
#
#
# 2024-06-30 08:40:20,527 INFO sqlalchemy.engine.Engine [no key 0.00091s] ()
# 2024-06-30 08:40:20,535 INFO sqlalchemy.engine.Engine
# CREATE TABLE conversation_message_association (
# 	conversation_id INTEGER,
# 	message_id INTEGER,
# 	FOREIGN KEY(conversation_id) REFERENCES conversations (conversation_id),
# 	FOREIGN KEY(message_id) REFERENCES messages (message_id)
# )
#
#
# 2024-06-30 08:40:20,536 INFO sqlalchemy.engine.Engine [no key 0.00077s] ()
# 2024-06-30 08:40:20,549 INFO sqlalchemy.engine.Engine COMMIT
